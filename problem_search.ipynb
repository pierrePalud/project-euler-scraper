# %%
import pandas as pd

# %%
df = pd.read_csv('./result/project-euler-problems.csv')

# %% [markdown]
# # First 5 problems

# %%
df.head()
# Out:
#    number                       title  \
# 0       1        Multiples of 3 and 5
# 1       2      Even Fibonacci numbers
# 2       3        Largest prime factor
# 3       4  Largest palindrome product
# 4       5           Smallest multiple
#
#                                          description Published on  Solved by  \
# 0  If we list all the natural numbers below 10 th...   2001-10-05     939109
# 1  Each new term in the Fibonacci sequence is gen...   2001-10-19     747665
# 2  The prime factors of 13195 are 5, 7, 13 and 29...   2001-11-02     534715
# 3  A palindromic number reads the same both ways....   2001-11-16     472297
# 4  2520 is the smallest number that can be divide...   2001-11-30     476679
#
#    Difficulty rating            Solved On  Solved
# 0                5.0  2016-08-01 21:30:00    True
# 1                5.0  2016-08-01 21:31:00    True
# 2                5.0  2016-08-01 21:31:00    True
# 3                5.0  2016-08-01 21:32:00    True
# ...

# %% [markdown]
# # Easy problems yet to solve

# %%
df[(df['Difficulty rating']<=15) & ~df['Solved']]
# Out:
#      number                                    title  \
# 61       62                       Cubic permutations
# 70       71                        Ordered fractions
# 72       73            Counting fractions in a range
# 73       74                   Digit factorial chains
# 75       76                      Counting summations
# 300     301                                      Nim
# 345     346                          Strong Repunits
# 346     347  Largest integer divisible by two primes
# 356     357                Prime generating integers
# 380     381                      (prime-k) factorial
# 386     387                          Harshad Numbers
# 503     504                     Square on the Inside
# 548     549               Divisibility of factorials
# 621     622                          Riffle Shuffles
# 649     650             Divisors of Binomial Product
# 683     684                        Inverse Digit Sum
# 685     686                            Powers of Two
# ...
